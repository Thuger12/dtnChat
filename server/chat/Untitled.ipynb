# %%
import psycopg2 as engine
con = engine.connect("postgresql://postgres:postgres@localhost:5432/rpserver")

# %%
with con.cursor() as cur:
    cur.execute("""SELECT * FROM spot""")
    m = cur.fetchall()
    print(m)
# Out:
# [(5, 'Gabrovo2', '(10.324,1.21421)', None, None), (8, 'Dram', '(10.324,1.21421)', None, None), (11, 'Gabrovo1234', '(10,23)', None, None), (13, 'Gabrovo12345', '(10,23)', None, None), (15, 'NewGabrovo', '(10,23)', 'Somethin about this spot', None)]
